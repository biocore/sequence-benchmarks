# %%
# %matplotlib inline
import pandas as pd

comparison = pd.concat([
    pd.DataFrame.from_csv("./biopy.csv"),
    pd.DataFrame.from_csv("./cogent.csv"),
    pd.DataFrame.from_csv("./skbio.csv"),
    pd.DataFrame.from_csv("./skbio023.csv"),
], axis=1)
comparison
# Out:
#                           biopython  pycogent  scikit-bio master  \
# degap_all                  0.011013  0.015875           0.008200
# object_creation            0.000059  0.003168           0.000576
# object_creation_validate   0.048866  0.003235           0.002241
# reverse_complement         0.000683  0.013738           1.533888
#
#                           scikit-bio 0.2.3
# degap_all                         0.078908
# object_creation                   0.000096
# object_creation_validate          0.007518
# reverse_complement                0.016737

# %%
comparison.plot(kind='bar', logy=True)

# %%
comparison[1:2].plot(kind='bar', logy=True)

# %%
comparison[2:3].plot(kind='bar', logy=True)

# %%
comparison[3:4].plot(kind='bar', logy=True)
