# %%
import pandas as pd

# %run 'biopython-py2.ipynb'
# %run 'skbio-master-py2.ipynb'
# %run 'pycogent-py2.ipynb'
# Out:
# 10000000 loops, best of 3: 88.2 ns per loop
# 10000000 loops, best of 3: 87.5 ns per loop
# 10000000 loops, best of 3: 88.6 ns per loop
# 10000000 loops, best of 3: 89.9 ns per loop
# 10000000 loops, best of 3: 90.6 ns per loop
# 10000000 loops, best of 3: 88.1 ns per loop
# 10000000 loops, best of 3: 90.4 ns per loop
# 10000000 loops, best of 3: 89.6 ns per loop
# 10000000 loops, best of 3: 91.3 ns per loop
# 10000000 loops, best of 3: 89.1 ns per loop
# 10000000 loops, best of 3: 86.1 ns per loop
# 10000000 loops, best of 3: 83 ns per loop
# 10000000 loops, best of 3: 91.2 ns per loop
# 10000000 loops, best of 3: 90.2 ns per loop
# 10000000 loops, best of 3: 82.1 ns per loop
# 10000000 loops, best of 3: 88.9 ns per loop
# 10000000 loops, best of 3: 77.3 ns per loop
# The slowest run took 13.33 times longer than the fastest. This could mean that an intermediate result is being cached
# 10000000 loops, best of 3: 89.4 ns per loop

# %%
pd.concat([skbio_benchmark.as_series(), cogent_benchmark.as_series(), biopython_benchmark.as_series()], axis=1)
# Out:
#                          scikit-bio master      pycogent     biopython
# degap_all                     9.133918e-08           NaN           NaN
# expand_degenerates            8.214760e-08           NaN           NaN
# filter_fasta_to_no_gaps       8.960891e-08           NaN           NaN
# filter_invalid_seqs           9.120829e-08           NaN           NaN
# find_motif_in_gapped          7.728851e-08           NaN           NaN
# gc_content                    8.891861e-08           NaN           NaN
# kmer_count_25                 8.605890e-08           NaN           NaN
# kmer_count_5                  8.906701e-08           NaN           NaN
# object_creation               8.747110e-08  8.944781e-08  8.820879e-08
# rc_find_motif                 9.020891e-08           NaN           NaN
# read_fasta_file               8.859069e-08           NaN           NaN
# reverse_complement            8.994660e-08           NaN           NaN
# reverse_translate             9.035540e-08           NaN           NaN
# search_for_motif              9.056840e-08           NaN           NaN
# translate                     8.813150e-08           NaN           NaN
# validate_chars                8.302000e-08           NaN           NaN
