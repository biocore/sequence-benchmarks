# %%
# %matplotlib inline
import pandas as pd

comparison = pd.concat([
    pd.DataFrame.from_csv("./biopy.csv"),
    pd.DataFrame.from_csv("./cogent.csv"),
    pd.DataFrame.from_csv("./skbio.csv"),
    pd.DataFrame.from_csv("./skbio023.csv"),
], axis=1)
comparison
# Out:
#                              biopython   pycogent  scikit-bio master  \
# degap_all                 5.565252e-02   0.083680           0.039947
# expand_degenerates                 NaN   0.530239           8.105253
# filter_fasta_to_no_gaps   4.335129e-03        NaN                NaN
# filter_invalid_seqs                NaN   0.016136           0.011714
# find_motif_in_gapped      9.915869e-08   0.305472           0.083955
# gc_content                1.434766e-02   0.006235           0.014383
# kmer_count_25                      NaN  18.451622          11.976090
# kmer_count_5                       NaN  19.026649          11.990263
# object_creation           2.798719e-04   0.006493           0.003027
# object_creation_validate  2.453010e-01   0.015684           0.011209
# read_fasta_file           1.374483e+00   3.818473           1.094838
# reverse_complement        3.440380e-03   0.068133           8.134283
# search_for_motif          1.492240e+00   0.003414           0.016176
# translate                 1.619511e-01   0.052004           4.006457
# validate_chars                     NaN   0.039872           0.011638
#
#                           scikit-bio 0.2.3
# degap_all                         0.388181
# expand_degenerates                0.274964
# filter_fasta_to_no_gaps           0.000503
# filter_invalid_seqs               0.039460
# find_motif_in_gapped              3.160063
# gc_content                        0.043699
# kmer_count_25                     3.525696
# kmer_count_5                      3.516868
# object_creation                   0.000485
# object_creation_validate          0.037607
# read_fasta_file                   0.595741
# reverse_complement                0.085110
# search_for_motif                  0.000250
# translate                         1.187240
# validate_chars                    0.038591

# %%
comparison.plot(kind='barh', logx=True, figsize=(8, 20))
