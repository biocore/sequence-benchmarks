# %%
# %matplotlib inline
import pandas as pd

comparison = pd.concat([
    pd.DataFrame.from_csv("./biopy.csv"),
    pd.DataFrame.from_csv("./cogent.csv"),
    pd.DataFrame.from_csv("./skbio.csv"),
    pd.DataFrame.from_csv("./skbio023.csv"),
], axis=1)
comparison
# Out:
#                           biopython  pycogent  scikit-bio master  \
# degap_all                  0.011013  0.015875       3.951211e-02
# filter_invalid_seqs             NaN       NaN       8.225720e-08
# find_motif_in_gapped            NaN       NaN       8.264611e-02
# kmer_count_25                   NaN       NaN       1.158453e+01
# kmer_count_5                    NaN       NaN       1.166892e+01
# object_creation            0.000059  0.003168       3.059490e-03
# object_creation_validate   0.048866  0.003235       1.134242e-02
# read_fasta_file                 NaN       NaN       1.124022e+00
# reverse_complement         0.000683  0.013738       7.896027e+00
# search_for_motif                NaN       NaN       1.589566e-02
# translate                       NaN       NaN       4.049924e+00
# validate_chars                  NaN       NaN       8.965480e-08
#
#                           scikit-bio 0.2.3
# degap_all                         0.078908
# filter_invalid_seqs                    NaN
# find_motif_in_gapped                   NaN
# kmer_count_25                          NaN
# kmer_count_5                           NaN
# object_creation                   0.000096
# object_creation_validate          0.007518
# read_fasta_file                        NaN
# reverse_complement                0.016737
# search_for_motif                       NaN
# translate                              NaN
# validate_chars                         NaN

# %%
comparison.plot(kind='barh', logx=True, figsize=(8, 20))
