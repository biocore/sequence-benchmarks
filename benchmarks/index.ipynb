# %%
# %matplotlib inline
import pandas as pd

comparison = pd.concat([
    pd.DataFrame.from_csv("./biopy.csv"),
    pd.DataFrame.from_csv("./cogent.csv"),
    pd.DataFrame.from_csv("./skbio023.csv"),
    pd.DataFrame.from_csv("./skbio.csv"),
], axis=1)
pd.set_option('display.float_format', lambda x: '%.2e' % x)
comparison.sort("scikit-bio master", axis=0, inplace=True)
comparison
# Out:
#                           biopython  pycogent  scikit-bio 0.2.3  \
# object_creation            2.86e-04  6.48e-03          4.76e-04
# slice_at_midpoint          6.47e-04  1.76e-02          1.83e-03
# object_creation_validate   2.54e-01  1.57e-02          3.89e-02
# validate_chars             2.83e-01  3.99e-02          3.81e-02
# filter_invalid_seqs        2.48e-01  1.62e-02          3.78e-02
# gc_content                 1.46e-02  6.31e-03          4.30e-02
# reverse_complement         3.47e-03  6.73e-02          8.35e-02
# search_for_motif           1.26e+00  3.42e-03          2.44e-04
# degap_all                  5.61e-02  7.72e-02          3.96e-01
# find_motif_in_gapped            nan  3.05e-01          3.11e+00
# read_fasta_file            1.40e+00  3.76e+00          6.21e-01
# translate                  1.60e-01  5.20e-02          1.19e+00
# expand_degenerates              nan  5.28e-01          2.76e-01
# kmer_count_5               5.77e+00  1.90e+01          3.54e+00
# kmer_count_25              4.24e+00  1.87e+01          3.55e+00
# filter_fasta_to_no_gaps    3.32e-03       nan          5.06e-04
#
#                           scikit-bio master
# object_creation                    2.92e-03
# slice_at_midpoint                  6.69e-03
# object_creation_validate           1.18e-02
# validate_chars                     1.23e-02
# filter_invalid_seqs                1.23e-02
# gc_content                         1.44e-02
# reverse_complement                 1.45e-02
# search_for_motif                   1.65e-02
# degap_all                          4.05e-02
# find_motif_in_gapped               8.87e-02
# read_fasta_file                    1.10e+00
# translate                          3.92e+00
# expand_degenerates                 8.28e+00
# kmer_count_5                       1.19e+01
# kmer_count_25                      1.19e+01
# filter_fasta_to_no_gaps                 nan

# %%
comparison.iloc[::-1].plot(kind='barh', logx=True, figsize=(8, 20))

# %%
comparison.subtract(comparison['scikit-bio master'], axis=0).iloc[::-1].plot(kind='barh', figsize=(8, 20))

# %%
comparison.corr()
# Out:
#                    biopython  pycogent  scikit-bio 0.2.3  scikit-bio master
# biopython           1.00e+00  9.70e-01          9.30e-01           9.28e-01
# pycogent            9.70e-01  1.00e+00          8.06e-01           8.61e-01
# scikit-bio 0.2.3    9.30e-01  8.06e-01          1.00e+00           7.14e-01
# scikit-bio master   9.28e-01  8.61e-01          7.14e-01           1.00e+00
